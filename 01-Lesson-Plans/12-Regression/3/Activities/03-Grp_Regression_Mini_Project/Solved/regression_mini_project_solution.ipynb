# %%
import pandas as pd
import pipeline_utilities as p_util
from sklearn.linear_model import Lasso
from sklearn.linear_model import LinearRegression

# %%
# Create a list of DataFrames by using a list comprehension with read_csv
days = ['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Saturday']

dfs = [pd.read_csv(f'https://static.bc-edx.com/ai/ail-v-1-0/m12/lesson_3/datasets/garments-worker-productivity-{day}.csv') for day in days]

dfs[1]
# Out:
#          date   quarter  department     day  team  targeted_productivity  \
# 0    1/5/2015  Quarter1  finishing   Monday     1                   0.80
# 1    1/5/2015  Quarter1  finishing   Monday    11                   0.80
# 2    1/5/2015  Quarter1  finishing   Monday     4                   0.80
# 3    1/5/2015  Quarter1  finishing   Monday     3                   0.75
# 4    1/5/2015  Quarter1      sweing  Monday     9                   0.80
# ..        ...       ...         ...     ...   ...                    ...
# 194  3/9/2015  Quarter2      sweing  Monday     8                   0.65
# 195  3/9/2015  Quarter2      sweing  Monday     5                   0.60
# 196  3/9/2015  Quarter2      sweing  Monday     7                   0.50
# 197  3/9/2015  Quarter2   finishing  Monday    10                   0.70
# 198  3/9/2015  Quarter2   finishing  Monday     8                   0.65
#
#        smv     wip  over_time  incentive  idle_time  idle_men  \
# ...

# %%
dfs[1].isna().sum()
# Out:
# date                      0
# quarter                   0
# department                0
# day                       0
# team                      0
# targeted_productivity     0
# smv                       0
# wip                      83
# over_time                 0
# incentive                 0
# idle_time                 0
# idle_men                  0
# no_of_style_change        0
# no_of_workers             0
# actual_productivity       0
# dtype: int64

# %%
model_dict = {}
for df in dfs:
    print(df.iloc[0,3])
    model_dict[f"{df.iloc[0,3]}_model"] = p_util.prod_model_generator(df,LinearRegression)
    print("----------")
# Out:
# Sunday
# Mean Squared Error: 0.008172182032177759
# R-squared: 0.656696352397558
# Adjusted R-squared: 0.6439814024863564
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 4
#       2 for df in dfs:
#       3     print(df.iloc[0,3])
# ----> 4     model_dict[f"{df.iloc[0,3]}_model"] = p_util.prod_model_generator(df,LinearRegression)
#       5     print("----------")
#
# File c:\Users\hafto\OneDrive\Desktop\DU-VIRT-AI-PT-10-2023-U-LOLC\01-Lesson-Plans\12-Regression\3\Activities\03-Grp_Regression_Mini_Project\Solved\pipeline_utilities.py:62, in prod_model_generator(prod_df, model_name)
#      60 print(f"R-squared: {r2_value}")
#      61 print(f"Adjusted R-squared: {r2_adj_value}")
# ---> 62 print(f'Score: {pipeline.score(X_train,X_test)}')
#      63 if r2_adj_value < 0.4:
#      64     print("WARNING: LOW ADJUSTED R-SQUARED VALUE")
#
# ...

# %%
model_dict
# Out:
# {'Sunday_model': Pipeline(steps=[('Scale', StandardScaler(with_mean=False)),
#                  ('Linear Regression', Lasso())]),
#  'Monday_model': Pipeline(steps=[('Scale', StandardScaler(with_mean=False)),
#                  ('Linear Regression', Lasso())]),
#  'Tuesday_model': Pipeline(steps=[('Scale', StandardScaler(with_mean=False)),
#                  ('Linear Regression', Lasso())]),
#  'Wednesday_model': Pipeline(steps=[('Scale', StandardScaler(with_mean=False)),
#                  ('Linear Regression', Lasso())]),
#  'Thursday_model': Pipeline(steps=[('Scale', StandardScaler(with_mean=False)),
#                  ('Linear Regression', Lasso())]),
#  'Saturday_model': Pipeline(steps=[('Scale', StandardScaler(with_mean=False)),
#                  ('Linear Regression', Lasso())])}

# %%
x_train,x_test,y_train,y_test = p_util.preprocess_prod_data(dfs[1],'wip')

x_train.isna().sum()
# Out:
# team                     0
# targeted_productivity    0
# smv                      0
# over_time                0
# incentive                0
# idle_time                0
# idle_men                 0
# no_of_style_change       0
# no_of_workers            0
# actual_productivity      0
# date_1/12/2015           0
# date_1/19/2015           0
# date_1/26/2015           0
# date_1/5/2015            0
# date_2/16/2015           0
# date_2/2/2015            0
# date_2/23/2015           0
# date_2/9/2015            0
# date_3/2/2015            0
# date_3/9/2015            0
# quarter_Quarter1         0
# quarter_Quarter2         0
# quarter_Quarter3         0
# quarter_Quarter4         0
# department_sweing        0
# day_Monday               0
# dtype: int64
